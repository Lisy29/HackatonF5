# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar el archivo train.csv desde la misma carpeta
td = pd.read_csv('dataset_concatenado_con_desviacion.csv', low_memory=False)

# Ver las primeras filas del archivo
td.head()
# Out:
#     id     destination    route alternate_route departure_time arrival_time  \
# 0  1.0  Puerta del Sol  Linea 3         Linea 9          19:49        20:00
# 1  2.0  Plaza Castilla  Linea 9         Linea 7          02:23        02:36
# 2  3.0  Puerta del Sol  Linea 4         Linea 2          18:58        19:31
# 3  4.0          Retiro  Linea 1         Linea 8          13:40        14:00
# 4  5.0          Retiro  Linea 2         Linea 5          05:58        06:19
#
#   current_time           traffic_streets  distance_to_next_stop  \
# 0        19:58           Paseo del Prado                   2.12
# 1        02:50              Calle Atocha                   2.44
# 2        19:11    Calle de Bravo Murillo                   0.60
# 3        13:43  Calle de Guzmán el Bueno                   4.56
# 4        06:13              Calle Alcalá                   3.57
#
#    time_estimate  ... incident_description deviation fecha  medio_transporte  \
# 0           55.0  ...        Tráfico denso        sí   NaN               NaN
# 1           21.0  ...    Retraso por obras        sí   NaN               NaN
# 2           29.0  ...                  NaN        no   NaN               NaN
# 3           29.0  ...                  NaN        sí   NaN               NaN
# 4           48.0  ...                  NaN        no   NaN               NaN
#
#   linea pasajeros  tiempo_espera_min  puntualidad incidencias desviacion
# 0   NaN       NaN                NaN          NaN         NaN   2.789186
# 1   NaN       NaN                NaN          NaN         NaN   3.604428
# 2   NaN       NaN                NaN          NaN         NaN   3.053541
# 3   NaN       NaN                NaN          NaN         NaN   2.769928
# 4   NaN       NaN                NaN          NaN         NaN   2.175909
#
# [5 rows x 30 columns]
